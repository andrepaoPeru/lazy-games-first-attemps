# %%
################################################################################################################################
                                              #WELCOME TO THE LAZY TIC TAC TOE#
                                          #If you wanna play, please introduce YES#
################################################################################################################################
    
#Game code    

from IPython.display import clear_output

play=input('Do you wanna play The Lazy Tic Tac Toe?') 

if play.lower()=='yes':
    
    player1=input('\nPlayer 1, please introduce your name!\n')
    player2=input('\nPlayer 2, please introduce your name!\n')

    print(f'\n\t\t\t\t\tHello {player1.upper()} and {player2.upper()}!\n\n')
    print('**************************************************************************************************************\n')
    print(f'\n\t\t\t\t{player1.upper()} you will play with the symbol: X\n')
    print(f'\t\t\t\t{player2.upper()} you will play with the symbol: O\n\n')
    print('**************************************************************************************************************\n')  
    print('To play this Lazy Tic Tac Toe, each player should input a number from 1 to 9, considering the following chart:\n')

    print('\t\t\t\t       1        |      2        |    3  ')
    print('\t\t\t\t-------------------------------------------')
    print('\t\t\t\t       4        |      5        |    6  ')
    print('\t\t\t\t-------------------------------------------')
    print('\t\t\t\t       7        |      8        |    9  ')

table_dic={1:'   ',2:'   ',3:'   ',4:'   ',5:'   ',6:'   ',7:'   ',8:'   ',9:'   '}

def juego(intro, jugada):
    lista=[' X ',' O '] 
    if jugada==1:
        table_dic[intro]=lista[0]
        print('**************************************************************************************************************\n')
        print(  table_dic[1]  +  ' | ' +  table_dic[2]  +' | '+  table_dic[3]  )
        print('----------------')
        print(  table_dic[4]  +  ' | ' +  table_dic[5]  +' | '+  table_dic[6]  )
        print('---------------')
        print(  table_dic[7]  +  ' | ' +  table_dic[8]  +' | '+  table_dic[9]  )
        print('**************************************************************************************************************\n')
    elif jugada==2:
        table_dic[intro2]=lista[1]
        print('**************************************************************************************************************\n')
        print(  table_dic[1]  +  ' | ' +  table_dic[2]  +' | '+  table_dic[3]  )
        print('----------------')
        print(  table_dic[4]  +  ' | ' +  table_dic[5]  +' | '+  table_dic[6]  )
        print('---------------')
        print(  table_dic[7]  +  ' | ' +  table_dic[8]  +' | '+  table_dic[9]  )
        print('**************************************************************************************************************\n')

        
def ganar (jugada):
    check=[' X ',' O ']
    if jugada==1:
        return ((table_dic[1]==check[0] and table_dic[2]==check[0] and table_dic[3]==check[0]) or
                (table_dic[4]==check[0] and table_dic[5]==check[0] and table_dic[6]==check[0]) or
                (table_dic[7]==check[0] and table_dic[8]==check[0] and table_dic[9]==check[0]) or
                (table_dic[1]==check[0] and table_dic[4]==check[0] and table_dic[7]==check[0]) or
                (table_dic[2]==check[0] and table_dic[5]==check[0] and table_dic[8]==check[0]) or
                (table_dic[3]==check[0] and table_dic[6]==check[0] and table_dic[9]==check[0]) or
                (table_dic[1]==check[0] and table_dic[5]==check[0] and table_dic[9]==check[0]) or
                (table_dic[3]==check[0] and table_dic[5]==check[0] and table_dic[7]==check[0]))
    if jugada==2:
        return ((table_dic[1]==check[1] and table_dic[2]==check[1] and table_dic[3]==check[1]) or
                (table_dic[4]==check[1] and table_dic[5]==check[1] and table_dic[6]==check[1]) or
                (table_dic[7]==check[1] and table_dic[8]==check[1] and table_dic[9]==check[1]) or
                (table_dic[1]==check[1] and table_dic[4]==check[1] and table_dic[7]==check[1]) or
                (table_dic[2]==check[1] and table_dic[5]==check[1] and table_dic[8]==check[1]) or
                (table_dic[3]==check[1] and table_dic[6]==check[1] and table_dic[9]==check[1]) or
                (table_dic[1]==check[1] and table_dic[5]==check[1] and table_dic[9]==check[1]) or
                (table_dic[3]==check[1] and table_dic[5]==check[1] and table_dic[7]==check[1])) 

win_var=False

while win_var==False:
    intro=(f'{player1.upper()} introduce your move!!')
    juego(intro, 1)
    win_var = ganar(1)
    
    intro2=(f'{player2.upper()} introduce your move!!')
    juego(intro2, 2)
    win_var = ganar(2)
else:
    print('GAME OVER')

# %%
################################################################################################################################
                                              #WELCOME TO THE LAZY TIC TAC TOE#
                                          #If you wanna play, please introduce YES#
################################################################################################################################
    
#Game code    

from IPython.display import clear_output

play=input('Do you wanna play The Lazy Tic Tac Toe?') 

if play.lower()=='yes':
    
    player1=input('\nPlayer 1, please introduce your name!\n')
    player2=input('\nPlayer 2, please introduce your name!\n')

    print(f'\n\t\t\t\t\tHello {player1.upper()} and {player2.upper()}!\n\n')
    print('**************************************************************************************************************\n')
    print(f'\n\t\t\t\t{player1.upper()} you will play with the symbol: X\n')
    print(f'\t\t\t\t{player2.upper()} you will play with the symbol: O\n\n')
    print('**************************************************************************************************************\n')  
    print('To play this Lazy Tic Tac Toe, each player should input a number from 1 to 9, considering the following chart:\n')

    print('\t\t\t\t       1        |      2        |    3  ')
    print('\t\t\t\t-------------------------------------------')
    print('\t\t\t\t       4        |      5        |    6  ')
    print('\t\t\t\t-------------------------------------------')
    print('\t\t\t\t       7        |      8        |    9  ')

table_dic={1:'   ',2:'   ',3:'   ',4:'   ',5:'   ',6:'   ',7:'   ',8:'   ',9:'   '}

def juego(intro, jugada):
    lista=[' X ',' O '] 
    if jugada==1:
        table_dic[intro]=lista[0]
        print('**************************************************************************************************************\n')
        print(  table_dic[1]  +  ' | ' +  table_dic[2]  +' | '+  table_dic[3]  )
        print('----------------')
        print(  table_dic[4]  +  ' | ' +  table_dic[5]  +' | '+  table_dic[6]  )
        print('---------------')
        print(  table_dic[7]  +  ' | ' +  table_dic[8]  +' | '+  table_dic[9]  )
        print('**************************************************************************************************************\n')
    elif jugada==2:
        table_dic[intro2]=lista[1]
        print('**************************************************************************************************************\n')
        print(  table_dic[1]  +  ' | ' +  table_dic[2]  +' | '+  table_dic[3]  )
        print('----------------')
        print(  table_dic[4]  +  ' | ' +  table_dic[5]  +' | '+  table_dic[6]  )
        print('---------------')
        print(  table_dic[7]  +  ' | ' +  table_dic[8]  +' | '+  table_dic[9]  )
        print('**************************************************************************************************************\n')

        
def ganar (jugada):
    check=[' X ',' O ']
    if jugada==1:
        return ((table_dic[1]==check[0] and table_dic[2]==check[0] and table_dic[3]==check[0]) or
                (table_dic[4]==check[0] and table_dic[5]==check[0] and table_dic[6]==check[0]) or
                (table_dic[7]==check[0] and table_dic[8]==check[0] and table_dic[9]==check[0]) or
                (table_dic[1]==check[0] and table_dic[4]==check[0] and table_dic[7]==check[0]) or
                (table_dic[2]==check[0] and table_dic[5]==check[0] and table_dic[8]==check[0]) or
                (table_dic[3]==check[0] and table_dic[6]==check[0] and table_dic[9]==check[0]) or
                (table_dic[1]==check[0] and table_dic[5]==check[0] and table_dic[9]==check[0]) or
                (table_dic[3]==check[0] and table_dic[5]==check[0] and table_dic[7]==check[0]))
    if jugada==2:
        return ((table_dic[1]==check[1] and table_dic[2]==check[1] and table_dic[3]==check[1]) or
                (table_dic[4]==check[1] and table_dic[5]==check[1] and table_dic[6]==check[1]) or
                (table_dic[7]==check[1] and table_dic[8]==check[1] and table_dic[9]==check[1]) or
                (table_dic[1]==check[1] and table_dic[4]==check[1] and table_dic[7]==check[1]) or
                (table_dic[2]==check[1] and table_dic[5]==check[1] and table_dic[8]==check[1]) or
                (table_dic[3]==check[1] and table_dic[6]==check[1] and table_dic[9]==check[1]) or
                (table_dic[1]==check[1] and table_dic[5]==check[1] and table_dic[9]==check[1]) or
                (table_dic[3]==check[1] and table_dic[5]==check[1] and table_dic[7]==check[1])) 

win_var=False

while win_var==False:
    intro=(f'{player1.upper()} introduce your move!!')
    juego(intro, 1)
    win_var = ganar(1)
    
    intro2=(f'{player2.upper()} introduce your move!!')
    juego(intro2, 2)
    win_var = ganar(2)
else:
    print('GAME OVER')
